# %% [markdown]
# # 00 — NeuroVal-3D smoke test
#
# Verifies the pipeline imports + the perturbation benchmark runs end-to-end on synthetic reports.

# %%
# %load_ext autoreload
# %autoreload 2

import sys, pathlib
sys.path.insert(0, str(pathlib.Path('..').resolve() / 'src'))

# %%
import neuroval3d
print('neuroval3d', neuroval3d.__version__)

# %%
from neuroval3d.evaluation import run_benchmark
result = run_benchmark(use_synthetic=True, n_samples=24, n_per_report=3)
print(result.summary_table())

# %% [markdown]
# If the table renders with finite AUROC numbers, Phase 0 is healthy. Move to `01_vasari_demo.ipynb` next.
